# %%
#!/usr/bin/env python3
"""
main.py
=======
Entry point and configuration hub for the UNO-card symbol-candidate
preprocessing pipeline.

Usage:
    python main.py

Pipeline:
    1. Load image(s) from IMAGE_SOURCE            (io_utils.load_images_from)
       -- IMAGE_SOURCE may be a directory OR a single image file.
    2. Run the preprocessing chain on the batch   (preprocess_utils.preprocess_image)
       threshold -> morphology -> edges -> tile_image
                 -> remove_noise_contours -> tile_selection
    3. Persist the resulting symbol_candidates    (io_utils.save_images_to)
"""

from __future__ import annotations

from typing import Any, Dict

from io_utils import load_images_from, save_images_to
from preprocess_utils import preprocess_image
from model_utils import save_dataset_to


# ============================================================================
# CONFIGURATION
# ============================================================================

# ---- I/O ----
# IMAGE_SOURCE may be either a directory (batch mode) or a single image file
# (single-image mode). When it's a directory, IMAGE_GLOB filters its contents;
# when it's a file, IMAGE_GLOB is ignored.
#IMAGE_SOURCE = "./data/train_images/L1000983.jpg"   # single-image mode
IMAGE_SOURCE = "./data/train_images"              # batch mode
OUTPUT_DIR  = "./tile"                              # candidate tiles go here
IMAGE_GLOB  = "*.jpg"                               # used only in batch mode
SAVE_FORMAT = "png"                                 # extension for saved tiles

# ---- diagnostics ----
SHOW_PLOTS = False   # master toggle: True renders every stage's matplotlib
                    # figure for every image; False runs silently.

# ---- thresholding (HSV white-bg filter) ----
SAT_MAX = 40        # HSV saturation below this -> candidate background
VAL_MIN = 180       # HSV value above this      -> candidate background

# ---- morphology / mask cleanup ----
MEDIAN_KSIZE  = 3   # 0 to skip
OPEN_KSIZE    = 3   # 0 to skip
CLOSE_KSIZE   = 3   # 0 to skip
MIN_BLOB_AREA = 20  # 0 to skip
SMOOTH_KSIZE  = 5   # Gaussian-then-rethreshold contour smoothing; 0 to skip

# ---- edges ----
SOBEL_KSIZE = 3

# ---- tiling geometry ----
TILE_SIZE = 99        # square window in px
OVERLAP   = 2.0 / 3.0 # fractional overlap -> stride = round(TILE_SIZE * (1 - OVERLAP))

# ---- noise removal (per-tile contour cleanup, contour_utils) ----
# After tiling, every tile is cleaned by remove_noise_contours: contours that
# are too small, or clipped by the tile frame, are dropped before selection.
NOISE_MIN_PIXELS  = 70   # drop contours with fewer than this many pixels
NOISE_EDGE_MARGIN = 2     # drop contours within this many px of a tile edge
# NOISE_FG_THRESHOLD: intensity above which a tile pixel counts as "foreground"
# for contour labeling. Left unset here -> preprocess_image defaults it to
# EDGE_THRESH, so the noise step and tile selection agree on what an edge pixel
# is. To override, add e.g. fg_threshold=30 to PIPELINE_KW below.

# ---- tile selection ----
EDGE_THRESH    = 20   # pixel intensity above which a Sobel pixel is "edge"
EDGE_KEEP_FRAC = 0.03 # keep tile when edge-pixel fraction >= this

# ---- reproducibility ----
SEED = 42


# Bundle the stage overrides we want preprocess_image to use.
# Keys must be parameter names accepted by preprocess_image (see _STAGE_PARAMS
# in preprocess_utils); an unrecognised key now raises TypeError instead of
# being silently ignored.
PIPELINE_KW: Dict[str, Any] = dict(
    sat_max=SAT_MAX, val_min=VAL_MIN,
    median_ksize=MEDIAN_KSIZE, open_ksize=OPEN_KSIZE,
    close_ksize=CLOSE_KSIZE, min_blob_area=MIN_BLOB_AREA,
    smooth_ksize=SMOOTH_KSIZE,
    ksize=SOBEL_KSIZE,
    tile_size=TILE_SIZE, overlap=OVERLAP,
    min_pixels=NOISE_MIN_PIXELS, edge_margin=NOISE_EDGE_MARGIN,
    edge_thresh=EDGE_THRESH, edge_keep_frac=EDGE_KEEP_FRAC,
    seed=SEED,
)

# %%
images = load_images_from(IMAGE_SOURCE, IMAGE_GLOB)

results = preprocess_image(images, show_plots=SHOW_PLOTS, **PIPELINE_KW)

# --- export candidates as a labelled-dataset skeleton ---------------------
# Pure addition: persists `results` to ./classifier_candidates_dataset/
# (routed L10007xx / L10008xx / L10009xx) without altering the pipeline.
save_dataset_to(results)
# cards = read_cards(images)
# symbol = classifer(results)
# game state = attribute symbols to cards(s)
# export (csv)

print("\n=== save phase ===")
for filename, symbol_candidates in results.items():
    save_images_to(OUTPUT_DIR, filename, symbol_candidates,
                    fmt=SAVE_FORMAT)

total = sum(len(v) for v in results.values())
print(f"\nDone. {total} candidate tile(s) across {len(results)} image(s).")
# Out:
# loaded 81 image(s) from ./data/train_images
#
# === preprocess_image: L1000770 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 41 / discarded 9439 (keep ratio 0.004)
#   kept edge-frac: min=0.032 mean=0.049 max=0.087
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 41 candidate tile(s)
#   translation   : mean |offset| = 18.87 px (max 40.48 px)
#   rotation      : mean |angle|  = 40.28 deg (max 88.84 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000771 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 43 / discarded 9437 (keep ratio 0.005)
#   kept edge-frac: min=0.031 mean=0.048 max=0.071
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 43 candidate tile(s)
#   translation   : mean |offset| = 20.55 px (max 34.98 px)
#   rotation      : mean |angle|  = 23.74 deg (max 84.69 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000772 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 71 / discarded 9409 (keep ratio 0.007)
#   kept edge-frac: min=0.030 mean=0.055 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 71 candidate tile(s)
#   translation   : mean |offset| = 18.72 px (max 36.31 px)
#   rotation      : mean |angle|  = 38.74 deg (max 88.97 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000773 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 51 / discarded 9429 (keep ratio 0.005)
#   kept edge-frac: min=0.030 mean=0.047 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 51 candidate tile(s)
#   translation   : mean |offset| = 19.72 px (max 35.30 px)
#   rotation      : mean |angle|  = 36.18 deg (max 83.90 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000774 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 74 / discarded 9406 (keep ratio 0.008)
#   kept edge-frac: min=0.031 mean=0.049 max=0.081
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 74 candidate tile(s)
#   translation   : mean |offset| = 20.51 px (max 34.55 px)
#   rotation      : mean |angle|  = 35.34 deg (max 89.32 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000775 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 68 / discarded 9412 (keep ratio 0.007)
#   kept edge-frac: min=0.030 mean=0.049 max=0.085
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 68 candidate tile(s)
#   translation   : mean |offset| = 20.14 px (max 34.33 px)
#   rotation      : mean |angle|  = 46.86 deg (max 94.26 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000776 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 46 / discarded 9434 (keep ratio 0.005)
#   kept edge-frac: min=0.031 mean=0.054 max=0.085
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 46 candidate tile(s)
#   translation   : mean |offset| = 17.38 px (max 31.29 px)
#   rotation      : mean |angle|  = 43.25 deg (max 88.07 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000777 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 44 / discarded 9436 (keep ratio 0.005)
#   kept edge-frac: min=0.031 mean=0.046 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 44 candidate tile(s)
#   translation   : mean |offset| = 19.87 px (max 35.85 px)
#   rotation      : mean |angle|  = 38.16 deg (max 87.62 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000778 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 42 / discarded 9438 (keep ratio 0.004)
#   kept edge-frac: min=0.030 mean=0.048 max=0.069
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 42 candidate tile(s)
#   translation   : mean |offset| = 19.53 px (max 31.68 px)
#   rotation      : mean |angle|  = 54.72 deg (max 91.13 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000779 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 51 / discarded 9429 (keep ratio 0.005)
#   kept edge-frac: min=0.031 mean=0.043 max=0.096
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 51 candidate tile(s)
#   translation   : mean |offset| = 19.11 px (max 35.16 px)
#   rotation      : mean |angle|  = 30.24 deg (max 85.16 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000780 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 48 / discarded 9432 (keep ratio 0.005)
#   kept edge-frac: min=0.034 mean=0.049 max=0.083
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 48 candidate tile(s)
#   translation   : mean |offset| = 22.75 px (max 41.51 px)
#   rotation      : mean |angle|  = 47.12 deg (max 86.63 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000781 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 31 / discarded 9449 (keep ratio 0.003)
#   kept edge-frac: min=0.030 mean=0.044 max=0.072
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 31 candidate tile(s)
#   translation   : mean |offset| = 18.81 px (max 36.77 px)
#   rotation      : mean |angle|  = 54.45 deg (max 88.60 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000782 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 45 / discarded 9435 (keep ratio 0.005)
#   kept edge-frac: min=0.034 mean=0.054 max=0.109
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 45 candidate tile(s)
#   translation   : mean |offset| = 17.67 px (max 33.98 px)
#   rotation      : mean |angle|  = 45.73 deg (max 83.55 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000783 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 37 / discarded 9443 (keep ratio 0.004)
#   kept edge-frac: min=0.031 mean=0.052 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 37 candidate tile(s)
#   translation   : mean |offset| = 18.83 px (max 39.86 px)
#   rotation      : mean |angle|  = 48.29 deg (max 84.11 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000784 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 41 / discarded 9439 (keep ratio 0.004)
#   kept edge-frac: min=0.030 mean=0.049 max=0.088
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 41 candidate tile(s)
#   translation   : mean |offset| = 19.45 px (max 40.10 px)
#   rotation      : mean |angle|  = 70.10 deg (max 88.29 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000785 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 39 / discarded 9441 (keep ratio 0.004)
#   kept edge-frac: min=0.030 mean=0.054 max=0.080
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 39 candidate tile(s)
#   translation   : mean |offset| = 19.20 px (max 41.38 px)
#   rotation      : mean |angle|  = 54.05 deg (max 85.56 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000786 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 23 / discarded 9457 (keep ratio 0.002)
#   kept edge-frac: min=0.033 mean=0.053 max=0.083
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 23 candidate tile(s)
#   translation   : mean |offset| = 17.25 px (max 34.82 px)
#   rotation      : mean |angle|  = 46.38 deg (max 85.06 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000787 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 34 / discarded 9446 (keep ratio 0.004)
#   kept edge-frac: min=0.030 mean=0.052 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 34 candidate tile(s)
#   translation   : mean |offset| = 18.65 px (max 33.87 px)
#   rotation      : mean |angle|  = 47.56 deg (max 90.56 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000788 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 45 / discarded 9435 (keep ratio 0.005)
#   kept edge-frac: min=0.030 mean=0.045 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 45 candidate tile(s)
#   translation   : mean |offset| = 20.00 px (max 38.81 px)
#   rotation      : mean |angle|  = 37.26 deg (max 81.08 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000789 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 45 / discarded 9435 (keep ratio 0.005)
#   kept edge-frac: min=0.031 mean=0.042 max=0.067
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 45 candidate tile(s)
#   translation   : mean |offset| = 20.58 px (max 37.69 px)
#   rotation      : mean |angle|  = 40.79 deg (max 91.36 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000790 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 58 / discarded 9422 (keep ratio 0.006)
#   kept edge-frac: min=0.030 mean=0.051 max=0.087
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 58 candidate tile(s)
#   translation   : mean |offset| = 20.67 px (max 37.47 px)
#   rotation      : mean |angle|  = 35.57 deg (max 71.74 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000791 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 52 / discarded 9428 (keep ratio 0.005)
#   kept edge-frac: min=0.030 mean=0.047 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 52 candidate tile(s)
#   translation   : mean |offset| = 19.54 px (max 36.14 px)
#   rotation      : mean |angle|  = 51.27 deg (max 88.27 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000836 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 25 / discarded 9455 (keep ratio 0.003)
#   kept edge-frac: min=0.032 mean=0.047 max=0.080
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 25 candidate tile(s)
#   translation   : mean |offset| = 19.81 px (max 31.04 px)
#   rotation      : mean |angle|  = 46.05 deg (max 88.38 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000837 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 36 / discarded 9444 (keep ratio 0.004)
#   kept edge-frac: min=0.031 mean=0.046 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 36 candidate tile(s)
#   translation   : mean |offset| = 19.97 px (max 35.05 px)
#   rotation      : mean |angle|  = 42.43 deg (max 86.34 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000838 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 30 / discarded 9450 (keep ratio 0.003)
#   kept edge-frac: min=0.033 mean=0.047 max=0.087
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 30 candidate tile(s)
#   translation   : mean |offset| = 19.94 px (max 41.28 px)
#   rotation      : mean |angle|  = 43.29 deg (max 88.07 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000839 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 33 / discarded 9447 (keep ratio 0.003)
#   kept edge-frac: min=0.030 mean=0.043 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 33 candidate tile(s)
#   translation   : mean |offset| = 19.49 px (max 38.01 px)
#   rotation      : mean |angle|  = 69.49 deg (max 98.05 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000840 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 33 / discarded 9447 (keep ratio 0.003)
#   kept edge-frac: min=0.031 mean=0.045 max=0.080
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 33 candidate tile(s)
#   translation   : mean |offset| = 18.82 px (max 37.82 px)
#   rotation      : mean |angle|  = 39.90 deg (max 79.70 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000841 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 42 / discarded 9438 (keep ratio 0.004)
#   kept edge-frac: min=0.031 mean=0.047 max=0.087
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 42 candidate tile(s)
#   translation   : mean |offset| = 20.29 px (max 34.56 px)
#   rotation      : mean |angle|  = 35.85 deg (max 81.39 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000842 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 42 / discarded 9438 (keep ratio 0.004)
#   kept edge-frac: min=0.030 mean=0.049 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 42 candidate tile(s)
#   translation   : mean |offset| = 19.26 px (max 37.09 px)
#   rotation      : mean |angle|  = 47.81 deg (max 92.17 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000843 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 46 / discarded 9434 (keep ratio 0.005)
#   kept edge-frac: min=0.030 mean=0.043 max=0.085
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 46 candidate tile(s)
#   translation   : mean |offset| = 18.30 px (max 35.25 px)
#   rotation      : mean |angle|  = 41.40 deg (max 84.76 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000844 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 50 / discarded 9430 (keep ratio 0.005)
#   kept edge-frac: min=0.031 mean=0.049 max=0.077
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 50 candidate tile(s)
#   translation   : mean |offset| = 20.93 px (max 36.66 px)
#   rotation      : mean |angle|  = 47.68 deg (max 79.26 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000846 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 42 / discarded 9438 (keep ratio 0.004)
#   kept edge-frac: min=0.032 mean=0.046 max=0.075
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 42 candidate tile(s)
#   translation   : mean |offset| = 19.18 px (max 38.58 px)
#   rotation      : mean |angle|  = 54.93 deg (max 81.00 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000847 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 39 / discarded 9441 (keep ratio 0.004)
#   kept edge-frac: min=0.030 mean=0.049 max=0.071
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 39 candidate tile(s)
#   translation   : mean |offset| = 19.66 px (max 29.58 px)
#   rotation      : mean |angle|  = 55.33 deg (max 88.59 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000848 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 42 / discarded 9438 (keep ratio 0.004)
#   kept edge-frac: min=0.030 mean=0.050 max=0.088
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 42 candidate tile(s)
#   translation   : mean |offset| = 18.24 px (max 35.80 px)
#   rotation      : mean |angle|  = 41.86 deg (max 81.35 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000849 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 51 / discarded 9429 (keep ratio 0.005)
#   kept edge-frac: min=0.032 mean=0.048 max=0.081
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 51 candidate tile(s)
#   translation   : mean |offset| = 18.95 px (max 35.87 px)
#   rotation      : mean |angle|  = 50.04 deg (max 90.79 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000850 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 53 / discarded 9427 (keep ratio 0.006)
#   kept edge-frac: min=0.030 mean=0.053 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 53 candidate tile(s)
#   translation   : mean |offset| = 17.68 px (max 33.27 px)
#   rotation      : mean |angle|  = 44.32 deg (max 90.69 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000851 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 32 / discarded 9448 (keep ratio 0.003)
#   kept edge-frac: min=0.038 mean=0.052 max=0.073
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 32 candidate tile(s)
#   translation   : mean |offset| = 19.44 px (max 31.42 px)
#   rotation      : mean |angle|  = 42.99 deg (max 78.32 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000852 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 33 / discarded 9447 (keep ratio 0.003)
#   kept edge-frac: min=0.032 mean=0.055 max=0.087
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 33 candidate tile(s)
#   translation   : mean |offset| = 20.46 px (max 35.57 px)
#   rotation      : mean |angle|  = 42.72 deg (max 71.92 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000853 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 57 / discarded 9423 (keep ratio 0.006)
#   kept edge-frac: min=0.030 mean=0.050 max=0.092
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 57 candidate tile(s)
#   translation   : mean |offset| = 20.00 px (max 42.71 px)
#   rotation      : mean |angle|  = 44.63 deg (max 87.91 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000855 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 55 / discarded 9425 (keep ratio 0.006)
#   kept edge-frac: min=0.030 mean=0.048 max=0.078
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 55 candidate tile(s)
#   translation   : mean |offset| = 20.42 px (max 39.07 px)
#   rotation      : mean |angle|  = 49.76 deg (max 90.35 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000856 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 19 / discarded 9461 (keep ratio 0.002)
#   kept edge-frac: min=0.032 mean=0.048 max=0.069
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 19 candidate tile(s)
#   translation   : mean |offset| = 18.12 px (max 36.73 px)
#   rotation      : mean |angle|  = 58.65 deg (max 92.90 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000857 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 40 / discarded 9440 (keep ratio 0.004)
#   kept edge-frac: min=0.031 mean=0.046 max=0.079
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 40 candidate tile(s)
#   translation   : mean |offset| = 18.26 px (max 37.42 px)
#   rotation      : mean |angle|  = 52.65 deg (max 88.87 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000902 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 132 / discarded 9348 (keep ratio 0.014)
#   kept edge-frac: min=0.031 mean=0.042 max=0.077
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 132 candidate tile(s)
#   translation   : mean |offset| = 20.18 px (max 39.78 px)
#   rotation      : mean |angle|  = 44.39 deg (max 83.93 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000903 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 114 / discarded 9366 (keep ratio 0.012)
#   kept edge-frac: min=0.031 mean=0.041 max=0.078
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 114 candidate tile(s)
#   translation   : mean |offset| = 18.63 px (max 35.20 px)
#   rotation      : mean |angle|  = 47.56 deg (max 86.11 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000904 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 130 / discarded 9350 (keep ratio 0.014)
#   kept edge-frac: min=0.031 mean=0.043 max=0.081
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 130 candidate tile(s)
#   translation   : mean |offset| = 19.62 px (max 40.07 px)
#   rotation      : mean |angle|  = 42.09 deg (max 87.63 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000905 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 104 / discarded 9376 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.041 max=0.073
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 104 candidate tile(s)
#   translation   : mean |offset| = 19.14 px (max 38.80 px)
#   rotation      : mean |angle|  = 45.82 deg (max 89.04 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000906 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 130 / discarded 9350 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.043 max=0.081
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 130 candidate tile(s)
#   translation   : mean |offset| = 19.19 px (max 39.76 px)
#   rotation      : mean |angle|  = 46.56 deg (max 84.72 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000907 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 129 / discarded 9351 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.044 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 129 candidate tile(s)
#   translation   : mean |offset| = 20.35 px (max 41.44 px)
#   rotation      : mean |angle|  = 50.57 deg (max 88.99 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000908 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 148 / discarded 9332 (keep ratio 0.016)
#   kept edge-frac: min=0.030 mean=0.044 max=0.085
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 148 candidate tile(s)
#   translation   : mean |offset| = 20.07 px (max 43.83 px)
#   rotation      : mean |angle|  = 54.98 deg (max 89.39 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000909 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 113 / discarded 9367 (keep ratio 0.012)
#   kept edge-frac: min=0.030 mean=0.042 max=0.079
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 113 candidate tile(s)
#   translation   : mean |offset| = 19.67 px (max 39.20 px)
#   rotation      : mean |angle|  = 45.23 deg (max 84.07 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000910 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 146 / discarded 9334 (keep ratio 0.015)
#   kept edge-frac: min=0.030 mean=0.043 max=0.080
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 146 candidate tile(s)
#   translation   : mean |offset| = 19.72 px (max 39.80 px)
#   rotation      : mean |angle|  = 50.19 deg (max 86.30 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000911 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 102 / discarded 9378 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.041 max=0.074
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 102 candidate tile(s)
#   translation   : mean |offset| = 18.04 px (max 39.69 px)
#   rotation      : mean |angle|  = 47.31 deg (max 86.78 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000912 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 114 / discarded 9366 (keep ratio 0.012)
#   kept edge-frac: min=0.030 mean=0.041 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 114 candidate tile(s)
#   translation   : mean |offset| = 18.23 px (max 39.56 px)
#   rotation      : mean |angle|  = 53.94 deg (max 84.50 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000913 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 131 / discarded 9349 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.044 max=0.085
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 131 candidate tile(s)
#   translation   : mean |offset| = 19.63 px (max 42.22 px)
#   rotation      : mean |angle|  = 48.48 deg (max 84.62 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000914 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 115 / discarded 9365 (keep ratio 0.012)
#   kept edge-frac: min=0.030 mean=0.041 max=0.087
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 115 candidate tile(s)
#   translation   : mean |offset| = 18.95 px (max 41.67 px)
#   rotation      : mean |angle|  = 50.60 deg (max 84.43 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000915 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 133 / discarded 9347 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.044 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 133 candidate tile(s)
#   translation   : mean |offset| = 19.49 px (max 39.32 px)
#   rotation      : mean |angle|  = 43.61 deg (max 87.54 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000916 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 106 / discarded 9374 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.044 max=0.084
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 106 candidate tile(s)
#   translation   : mean |offset| = 18.95 px (max 42.43 px)
#   rotation      : mean |angle|  = 55.22 deg (max 88.48 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000917 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 108 / discarded 9372 (keep ratio 0.011)
#   kept edge-frac: min=0.031 mean=0.042 max=0.104
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 108 candidate tile(s)
#   translation   : mean |offset| = 18.85 px (max 39.25 px)
#   rotation      : mean |angle|  = 43.31 deg (max 88.86 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000918 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 101 / discarded 9379 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.041 max=0.104
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 101 candidate tile(s)
#   translation   : mean |offset| = 18.67 px (max 39.35 px)
#   rotation      : mean |angle|  = 47.05 deg (max 90.15 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000919 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 119 / discarded 9361 (keep ratio 0.013)
#   kept edge-frac: min=0.030 mean=0.042 max=0.103
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 119 candidate tile(s)
#   translation   : mean |offset| = 18.99 px (max 39.47 px)
#   rotation      : mean |angle|  = 53.15 deg (max 89.05 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000920 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 131 / discarded 9349 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.042 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 131 candidate tile(s)
#   translation   : mean |offset| = 19.70 px (max 39.40 px)
#   rotation      : mean |angle|  = 48.00 deg (max 89.51 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000964 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 97 / discarded 9383 (keep ratio 0.010)
#   kept edge-frac: min=0.030 mean=0.041 max=0.074
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 97 candidate tile(s)
#   translation   : mean |offset| = 18.80 px (max 39.81 px)
#   rotation      : mean |angle|  = 43.54 deg (max 83.60 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000965 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 94 / discarded 9386 (keep ratio 0.010)
#   kept edge-frac: min=0.030 mean=0.042 max=0.087
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 94 candidate tile(s)
#   translation   : mean |offset| = 18.62 px (max 40.03 px)
#   rotation      : mean |angle|  = 46.02 deg (max 82.85 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000966 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 100 / discarded 9380 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.040 max=0.076
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 100 candidate tile(s)
#   translation   : mean |offset| = 18.93 px (max 39.89 px)
#   rotation      : mean |angle|  = 45.77 deg (max 89.14 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000967 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 114 / discarded 9366 (keep ratio 0.012)
#   kept edge-frac: min=0.030 mean=0.043 max=0.080
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
# ...
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 91 candidate tile(s)
#   translation   : mean |offset| = 18.74 px (max 39.92 px)
#   rotation      : mean |angle|  = 45.68 deg (max 84.23 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000969 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 98 / discarded 9382 (keep ratio 0.010)
#   kept edge-frac: min=0.031 mean=0.043 max=0.074
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 98 candidate tile(s)
#   translation   : mean |offset| = 19.46 px (max 39.85 px)
#   rotation      : mean |angle|  = 40.92 deg (max 84.21 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000970 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 105 / discarded 9375 (keep ratio 0.011)
#   kept edge-frac: min=0.031 mean=0.040 max=0.074
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 105 candidate tile(s)
#   translation   : mean |offset| = 19.53 px (max 39.86 px)
#   rotation      : mean |angle|  = 42.70 deg (max 85.20 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000971 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 111 / discarded 9369 (keep ratio 0.012)
#   kept edge-frac: min=0.030 mean=0.042 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 111 candidate tile(s)
#   translation   : mean |offset| = 18.60 px (max 40.17 px)
#   rotation      : mean |angle|  = 45.85 deg (max 84.21 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000972 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 116 / discarded 9364 (keep ratio 0.012)
#   kept edge-frac: min=0.031 mean=0.042 max=0.076
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 116 candidate tile(s)
#   translation   : mean |offset| = 19.04 px (max 39.85 px)
#   rotation      : mean |angle|  = 45.79 deg (max 86.35 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000973 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 132 / discarded 9348 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.040 max=0.090
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 132 candidate tile(s)
#   translation   : mean |offset| = 19.21 px (max 39.90 px)
#   rotation      : mean |angle|  = 38.47 deg (max 89.77 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000974 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 115 / discarded 9365 (keep ratio 0.012)
#   kept edge-frac: min=0.030 mean=0.041 max=0.093
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 115 candidate tile(s)
#   translation   : mean |offset| = 18.73 px (max 38.43 px)
#   rotation      : mean |angle|  = 46.51 deg (max 91.19 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000975 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 132 / discarded 9348 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.043 max=0.086
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 132 candidate tile(s)
#   translation   : mean |offset| = 19.33 px (max 39.89 px)
#   rotation      : mean |angle|  = 40.92 deg (max 85.38 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000976 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 124 / discarded 9356 (keep ratio 0.013)
#   kept edge-frac: min=0.030 mean=0.042 max=0.077
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 124 candidate tile(s)
#   translation   : mean |offset| = 18.79 px (max 39.83 px)
#   rotation      : mean |angle|  = 43.49 deg (max 84.47 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000977 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 131 / discarded 9349 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.041 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 131 candidate tile(s)
#   translation   : mean |offset| = 19.75 px (max 40.08 px)
#   rotation      : mean |angle|  = 48.73 deg (max 88.95 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000978 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 120 / discarded 9360 (keep ratio 0.013)
#   kept edge-frac: min=0.030 mean=0.041 max=0.074
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 120 candidate tile(s)
#   translation   : mean |offset| = 19.01 px (max 39.79 px)
#   rotation      : mean |angle|  = 47.50 deg (max 93.32 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000979 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 108 / discarded 9372 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.042 max=0.081
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 108 candidate tile(s)
#   translation   : mean |offset| = 18.86 px (max 38.87 px)
#   rotation      : mean |angle|  = 42.74 deg (max 91.23 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000980 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 108 / discarded 9372 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.041 max=0.075
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 108 candidate tile(s)
#   translation   : mean |offset| = 18.53 px (max 39.76 px)
#   rotation      : mean |angle|  = 46.05 deg (max 82.95 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000981 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 106 / discarded 9374 (keep ratio 0.011)
#   kept edge-frac: min=0.030 mean=0.042 max=0.083
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 106 candidate tile(s)
#   translation   : mean |offset| = 18.54 px (max 40.18 px)
#   rotation      : mean |angle|  = 44.91 deg (max 83.74 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000982 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 131 / discarded 9349 (keep ratio 0.014)
#   kept edge-frac: min=0.030 mean=0.044 max=0.082
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 131 candidate tile(s)
#   translation   : mean |offset| = 19.38 px (max 40.22 px)
#   rotation      : mean |angle|  = 42.10 deg (max 83.35 deg)
# --------------------------------------------------
#
# === preprocess_image: L1000983 ===
# tile_selection
# --------------------------------------------------
#   parameters    : edge_thresh=20, edge_keep_frac=3.00%
#   geometry      : 120 cols x 79 rows = 9480 tiles (tile 99px, stride 33px)
#   result        : kept 129 / discarded 9351 (keep ratio 0.014)
#   kept edge-frac: min=0.031 mean=0.044 max=0.080
# --------------------------------------------------
# rotation_translation_correction
# --------------------------------------------------
#   parameters    : fg_threshold=20, max_iter=15, tol=0.5
#   rectified     : 129 candidate tile(s)
#   translation   : mean |offset| = 20.05 px (max 40.12 px)
#   rotation      : mean |angle|  = 43.54 deg (max 83.40 deg)
# --------------------------------------------------
#   note: template CSV 'Template labels.csv' not found; using default header ['image_name', 'label']
# save_dataset_to
# --------------------------------------------------
#   dataset root  : .\classifier_candidates_dataset
#   csv schema    : image_name,label
#   L10007xx  : saved this run 1029  |  csv rows 1029  (labelled 0)
#   L10008xx  : saved this run  800  |  csv rows  800  (labelled 0)
#   L10009xx  : saved this run 4568  |  csv rows 4568  (labelled 0)
#   total on disk : 6397 candidate tile(s)
# --------------------------------------------------
#
# === save phase ===
# saved 41 candidate tile(s) to ./tile\L1000770/
# saved 43 candidate tile(s) to ./tile\L1000771/
# saved 71 candidate tile(s) to ./tile\L1000772/
# saved 51 candidate tile(s) to ./tile\L1000773/
# saved 74 candidate tile(s) to ./tile\L1000774/
# saved 68 candidate tile(s) to ./tile\L1000775/
# saved 46 candidate tile(s) to ./tile\L1000776/
# saved 44 candidate tile(s) to ./tile\L1000777/
# saved 42 candidate tile(s) to ./tile\L1000778/
# saved 51 candidate tile(s) to ./tile\L1000779/
# saved 48 candidate tile(s) to ./tile\L1000780/
# saved 31 candidate tile(s) to ./tile\L1000781/
# saved 45 candidate tile(s) to ./tile\L1000782/
# saved 37 candidate tile(s) to ./tile\L1000783/
# saved 41 candidate tile(s) to ./tile\L1000784/
# saved 39 candidate tile(s) to ./tile\L1000785/
# saved 23 candidate tile(s) to ./tile\L1000786/
# saved 34 candidate tile(s) to ./tile\L1000787/
# saved 45 candidate tile(s) to ./tile\L1000788/
# saved 45 candidate tile(s) to ./tile\L1000789/
# saved 58 candidate tile(s) to ./tile\L1000790/
# saved 52 candidate tile(s) to ./tile\L1000791/
# saved 25 candidate tile(s) to ./tile\L1000836/
# saved 36 candidate tile(s) to ./tile\L1000837/
# saved 30 candidate tile(s) to ./tile\L1000838/
# saved 33 candidate tile(s) to ./tile\L1000839/
# saved 33 candidate tile(s) to ./tile\L1000840/
# saved 42 candidate tile(s) to ./tile\L1000841/
# saved 42 candidate tile(s) to ./tile\L1000842/
# saved 46 candidate tile(s) to ./tile\L1000843/
# saved 50 candidate tile(s) to ./tile\L1000844/
# saved 42 candidate tile(s) to ./tile\L1000846/
# saved 39 candidate tile(s) to ./tile\L1000847/
# saved 42 candidate tile(s) to ./tile\L1000848/
# saved 51 candidate tile(s) to ./tile\L1000849/
# saved 53 candidate tile(s) to ./tile\L1000850/
# saved 32 candidate tile(s) to ./tile\L1000851/
# saved 33 candidate tile(s) to ./tile\L1000852/
# saved 57 candidate tile(s) to ./tile\L1000853/
# saved 55 candidate tile(s) to ./tile\L1000855/
# saved 19 candidate tile(s) to ./tile\L1000856/
# saved 40 candidate tile(s) to ./tile\L1000857/
# saved 132 candidate tile(s) to ./tile\L1000902/
# saved 114 candidate tile(s) to ./tile\L1000903/
# saved 130 candidate tile(s) to ./tile\L1000904/
# saved 104 candidate tile(s) to ./tile\L1000905/
# saved 130 candidate tile(s) to ./tile\L1000906/
# saved 129 candidate tile(s) to ./tile\L1000907/
# saved 148 candidate tile(s) to ./tile\L1000908/
# saved 113 candidate tile(s) to ./tile\L1000909/
# saved 146 candidate tile(s) to ./tile\L1000910/
# saved 102 candidate tile(s) to ./tile\L1000911/
# saved 114 candidate tile(s) to ./tile\L1000912/
# saved 131 candidate tile(s) to ./tile\L1000913/
# saved 115 candidate tile(s) to ./tile\L1000914/
# saved 133 candidate tile(s) to ./tile\L1000915/
# saved 106 candidate tile(s) to ./tile\L1000916/
# saved 108 candidate tile(s) to ./tile\L1000917/
# saved 101 candidate tile(s) to ./tile\L1000918/
# saved 119 candidate tile(s) to ./tile\L1000919/
# saved 131 candidate tile(s) to ./tile\L1000920/
# saved 97 candidate tile(s) to ./tile\L1000964/
# saved 94 candidate tile(s) to ./tile\L1000965/
# saved 100 candidate tile(s) to ./tile\L1000966/
# saved 114 candidate tile(s) to ./tile\L1000967/
# saved 91 candidate tile(s) to ./tile\L1000968/
# saved 98 candidate tile(s) to ./tile\L1000969/
# saved 105 candidate tile(s) to ./tile\L1000970/
# saved 111 candidate tile(s) to ./tile\L1000971/
# saved 116 candidate tile(s) to ./tile\L1000972/
# saved 132 candidate tile(s) to ./tile\L1000973/
# saved 115 candidate tile(s) to ./tile\L1000974/
# saved 132 candidate tile(s) to ./tile\L1000975/
# saved 124 candidate tile(s) to ./tile\L1000976/
# saved 131 candidate tile(s) to ./tile\L1000977/
# saved 120 candidate tile(s) to ./tile\L1000978/
# saved 108 candidate tile(s) to ./tile\L1000979/
# saved 108 candidate tile(s) to ./tile\L1000980/
# saved 106 candidate tile(s) to ./tile\L1000981/
# saved 131 candidate tile(s) to ./tile\L1000982/
# saved 129 candidate tile(s) to ./tile\L1000983/
#
# Done. 6397 candidate tile(s) across 81 image(s).
